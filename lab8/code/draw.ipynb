# %%
from utilies import *
import cv2

# %% [markdown]
# Create the Folder `Outputs` if not exists.

# %%
if not os.path.exists('Outputs'):
	os.mkdir('Outputs')

# %% [markdown]
# Process the images.

# %%
for i in range(1, 3 + 1):
    input_image_name = 'img{}.jpg'.format(i)
    input_image_path = 'images/{}'.format(input_image_name)

    print('now processing: {} ......'.format(input_image_path))

    img_bgr = cv2.imread(input_image_path)
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    plt.imshow(img_rgb)
    plt.show()
    draw_color_histogram(img_rgb, input_image_name, f'Outputs/img{i}_color_histogram.jpg', True)

    img_grayscale = cv2.imread(input_image_path, cv2.IMREAD_GRAYSCALE)
    plt.imshow(img_grayscale, plt.cm.gray)
    plt.show()
    cv2.imwrite(f'Outputs/img{i}_grayscale.jpg', img_grayscale)
    
    draw_grayscale_histogram(img_grayscale, input_image_name, f'Outputs/img{i}_grayscale_histogram.jpg', True)
    draw_gradient_histogram(img_grayscale, input_image_name, f'Outputs/img{i}_gradient_histogram.jpg', True)
# Out:
# now processing: images/img1.jpg ......
# now processing: images/img2.jpg ......
# now processing: images/img3.jpg ......
